# %%
pip install PyPi
# Out:
# ...
#   Created wheel for PyPi: filename=pypi-2.1-py3-none-any.whl size=1357 sha256=9c2a2fc35744cd8b4a4a970a254e00b43e79a5de2abbc790b03c3cee3d519d5a
#   Stored in directory: c:\users\dinu\appdata\local\pip\cache\wheels\6e\bb\35\2b31808160dec7d2186ec14eca0b52c3f5a337d1aa40d87f59
# Successfully built PyPi
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import names

# %%
for i in range(0,55):
   print(names.get_first_name(gender='male'),' ',names.get_last_name())
# Out:
# Mark   Drake
# Damien   Sappington
# Shane   Glowacki
# Gregory   Ensor
# Christopher   Rozzi
# Robert   Abels
# James   Schwipps
# Henry   Vazquez
# Larry   Lim
# Bruce   Dettinger
# Scott   Hermans
# John   Perez
# Harvey   Lewis
# Ruben   Coleman
# John   Ghan
# William   Cavallaro
# Earl   Burney
# Bernard   Gibson
# Daniel   Enfinger
# Leonard   Davis
# Dale   Betz
# Richard   Davis
# Edward   Sabatini
# Brian   Davis
# Kristopher   Wiegand
# Robert   Mars
# Mark   Gaden
# Timothy   Silva
# Noe   Bryant
# Daniel   Dwyer
# Andrew   Crawford
# Randy   Mcbryde
# Roberto   Moore
# Joseph   Shorter
# Henry   Hoffstetter
# Michael   Stachura
# Lester   Sprenger
# Jay   Nagel
# Jeffrey   Kilian
# Brian   Johnson
# David   Miller
# Henry   Tate
# Michael   Tricarico
# Daniel   Stewart
# Arthur   Oshaughnessy
# Arthur   Dillion
# James   Adell
# Roy   Wilson
# James   Garcia
# Philip   Short
# Felipe   Thom
# Cedric   Hamilton
# Leonard   Key
# James   Dalrymple
# Eugene   Baker

# %%
for i in range(0,55):
   print(names.get_first_name(gender='Female'),' ',names.get_last_name())
# Out:
# Edwin   Thomas
# Marsha   Pena
# Teofila   Gallagher
# Craig   Bradley
# Michael   Neal
# Michael   Moore
# Elizabeth   Schneider
# Andrew   Maks
# Michael   Robinson
# Irene   Baumgardner
# Sharon   Flores
# Alexandria   Cureton
# Michelle   Hyatt
# Pam   Lewis
# Marianna   Evans
# Betty   Hayes
# Salena   Cooper
# John   Witaszek
# Kara   Stoll
# William   Windmeyer
# Eugene   Wright
# Henrietta   Bird
# Helen   Burchette
# Michael   Leach
# Veronica   Albrecht
# Joshua   Camacho
# Roberto   Brown
# Jayne   Varela
# Linda   Mendoza
# Abraham   Champagne
# Todd   Pullen
# Mark   Johnson
# Natalie   Carter
# Donald   Jeffers
# Linda   Kruger
# Cecilia   Cavalero
# Randy   Courter
# Hazel   Smith
# Shannon   Woody
# Denise   Brown
# John   Washington
# Shawn   Morrison
# Bethany   Stern
# Theresa   Esterbrook
# Jason   Johnson
# Ernesto   Peterson
# Vivian   Molina
# Dewey   Schiavone
# John   Gregg
# Sherry   Zager
# Philip   Greenleaf
# Debra   Guzman
# Samantha   Lane
# ...

# %%
pip install Faker
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from faker import Faker

# %%
fake.address()
# Out:
# '1078 Darrell Expressway\nMackenziechester, ND 85002'

# %%
fake = Faker()

for i in range(0,130):
   x = fake.address().replace('\n',',')
   print(x)
# Out:
# 2856 Crystal River Suite 333,Rogerhaven, KY 93784
# 50284 Steven Spring,Phillipstad, NY 12754
# 115 Hines Park Suite 059,West Allison, SC 41799
# 69156 Christina Valleys,Port Robertshire, AK 87749
# 1529 Dale Mountain,West Erika, WY 73085
# PSC 5764, Box 2431,APO AE 48146
# PSC 2316, Box 7584,APO AA 47250
# PSC 9433, Box 0272,APO AP 30893
# 01461 Lang Mission,Vincentberg, MT 41683
# 800 Sandra Overpass,Port Richard, CA 45878
# 9243 Murphy Coves,Port Theresa, MA 43208
# 958 Paul Prairie Apt. 453,Nguyenton, IL 27344
# 943 Kerri Pine Apt. 554,Port Debraview, CO 89031
# 634 Guzman Expressway Suite 762,South Marisa, CT 86928
# 1045 Foster Prairie Suite 204,Millerview, OH 96310
# 52020 Moore Route,Danielberg, IA 65384
# PSC 8150, Box 0153,APO AE 80961
# USS Hess,FPO AP 42713
# 63888 Adam Lights Apt. 840,New Alexanderburgh, WA 72605
# Unit 5987 Box 7538,DPO AE 91169
# 18489 Burns Summit,Kathrynmouth, ME 74482
# USNS Wheeler,FPO AE 74407
# 245 Daniel Brooks,Port Nicholas, KY 20950
# ...

# %%
import numpy as np

# %%
base = np.datetime64('1941-01-01')
days = np.arange(0, 29200)

for i in range(0,130):
    dob = base + np.random.choice(days)
    print(dob)
# Out:
# 2007-05-26
# 1965-03-17
# 1970-08-27
# 2005-10-23
# 1997-08-01
# 1944-07-22
# 2010-01-07
# 2010-07-01
# 1947-03-10
# 1975-03-01
# 1996-07-04
# 2002-03-21
# 1999-04-18
# 1980-05-17
# 2020-07-14
# 1971-10-04
# 1971-08-08
# 2016-11-28
# 2010-11-28
# 1997-10-31
# 2010-12-20
# 1958-02-04
# 1980-07-31
# 1986-06-21
# 1995-10-13
# 2003-03-28
# 1946-04-11
# 1991-04-14
# 1941-09-19
# 2005-09-12
# 2014-06-09
# 1944-04-14
# 1944-04-23
# 1951-07-01
# 1975-07-27
# 1972-11-23
# 2017-09-05
# 2015-03-20
# 2003-08-30
# 1959-06-28
# 1971-10-15
# 1999-01-01
# 1968-09-03
# 1982-01-27
# 1972-10-25
# 2012-08-26
# 2000-03-03
# 1942-10-29
# 2019-02-20
# 2000-10-27
# 1960-11-25
# 1981-03-18
# 1953-04-10
# 1958-09-13
# 1962-11-04
# 1951-09-17
# 1972-05-24
# 1943-12-29
# 1945-10-29
# 1982-07-25
# 2018-08-08
# 1965-07-25
# 1993-02-21
# 2015-01-22
# 1987-10-02
# 1970-07-11
# 1954-05-22
# 1956-07-11
# 1953-06-27
# 2008-08-14
# 1959-01-23
# 2011-02-01
# 1983-10-25
# 1974-12-21
# 1970-02-14
# 1966-12-27
# ...

# %%
80*365
# Out:
# 29200

# %%
base = np.arange(900, 999)
second = np.arange(1000000, 9999999)
for i in range(0,130):
    phone = str(np.random.choice(base)) + str(np.random.choice(second))
    print(phone)
# Out:
# 9253520427
# 9329939188
# 9873879792
# 9666715442
# 9576027756
# 9971637598
# 9884394021
# 6811127
# 7324177
# 1313786
# 5782396
# 1391904
# 6080617
# 7488221
# 8339334
# 4386665
# 6414396
# 6838132
# 4798081
# 6806057
# 7830249
# 1879863
# 8927573
# 3985501
# 6024742
# 9567471
# 7501919
# 3373766
# 3399298
# 6657520
# 9138246
# 1544250
# 1095271
# 8396786
# 1625481
# 1849204
# 9541581
# 6093563
# 7271568
# 3448069
# 8536883
# ...

# %%
import datetime
from calendar import monthrange
import numpy as np

arr_first = np.array([])
arr_second = np.array([])

for i in range(1, 13):
    base = datetime.datetime(2016, i, 1)
    max_days = monthrange(2016, i)[1]
    first = np.random.randint(0, max_days // 2)
    second =np.random.randint(max_days // 2, max_days)
    arr_first = np.append(arr_first, base + datetime.timedelta(days=first))
    arr_second = np.append(arr_second, base + datetime.timedelta(days=second))
    
print(arr_second)
# Out:
# [datetime.datetime(2016, 1, 25, 0, 0) datetime.datetime(2016, 2, 18, 0, 0)
#  datetime.datetime(2016, 3, 24, 0, 0) datetime.datetime(2016, 4, 22, 0, 0)
#  datetime.datetime(2016, 5, 22, 0, 0) datetime.datetime(2016, 6, 18, 0, 0)
#  datetime.datetime(2016, 7, 31, 0, 0) datetime.datetime(2016, 8, 20, 0, 0)
#  datetime.datetime(2016, 9, 29, 0, 0)
#  datetime.datetime(2016, 10, 19, 0, 0)
#  datetime.datetime(2016, 11, 29, 0, 0)
#  datetime.datetime(2016, 12, 30, 0, 0)]

# %%
base = np.datetime64('2020-06-01 00:00')
days = np.arange(0, 612000)

mins = np.arange(5, 120)

for i in range(0,205):
    start = base + np.random.choice(days)
    end = start + np.random.choice(mins)
    print(start,'#',end)
# Out:
# 2020-12-20T00:09 # 2020-12-20T01:08
# 2021-05-18T01:04 # 2021-05-18T01:30
# 2021-02-16T21:05 # 2021-02-16T21:58
# 2020-08-17T04:35 # 2020-08-17T05:25
# 2021-07-29T22:27 # 2021-07-29T23:08
# 2020-07-28T22:38 # 2020-07-29T00:37
# 2020-08-14T12:04 # 2020-08-14T13:30
# 2020-11-05T09:12 # 2020-11-05T09:22
# 2020-10-31T14:38 # 2020-10-31T15:16
# 2020-12-31T12:22 # 2020-12-31T13:59
# 2020-07-09T01:06 # 2020-07-09T01:23
# 2021-01-23T21:57 # 2021-01-23T23:03
# 2020-09-10T03:06 # 2020-09-10T05:02
# 2020-10-18T23:00 # 2020-10-19T00:32
# 2021-02-16T20:26 # 2021-02-16T20:54
# 2020-08-11T23:53 # 2020-08-12T00:33
# 2021-06-17T17:08 # 2021-06-17T17:59
# 2020-07-10T04:09 # 2020-07-10T05:30
# 2021-05-26T02:19 # 2021-05-26T02:40
# 2021-05-30T05:44 # 2021-05-30T06:33
# 2021-05-10T08:13 # 2021-05-10T09:47
# 2021-05-04T12:33 # 2021-05-04T12:48
# 2021-03-17T13:11 # 2021-03-17T13:33
# 2020-08-01T02:16 # 2020-08-01T04:04
# 2020-10-25T21:55 # 2020-10-25T22:47
# 2020-10-13T09:37 # 2020-10-13T10:00
# ...
